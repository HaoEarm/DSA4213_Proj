# %%
#import libraries
import pandas as pd

# %%
#Read the files
#Reflects the relevance of a tag to a movie on a scale of 0 to 1
#Closer to 1 is more relevant
genome_scores = pd.read_csv("Dataset/genome_scores.csv")

#tag descriptions
genome_tags = pd.read_csv("Dataset/genome_tags.csv")

#Contains movie information
movies = pd.read_csv("Dataset/movie.csv")

#ratings of movie by users
ratings = pd.read_csv("Dataset/rating.csv")

#tags applied to movies by users
tags = pd.read_csv("Dataset/tag.csv")

# %%
print(genome_scores[genome_scores['movieId'] == 1])
# Out:
#       movieId  tagId  relevance
# 0           1      1    0.02500
# 1           1      2    0.02500
# 2           1      3    0.05775
# 3           1      4    0.09675
# 4           1      5    0.14675
# ...       ...    ...        ...
# 1123        1   1124    0.04150
# 1124        1   1125    0.01925
# 1125        1   1126    0.03625
# 1126        1   1127    0.07775
# 1127        1   1128    0.02300
#
# [1128 rows x 3 columns]

# %%
genome_tags.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
unique_genome_tags = genome_tags['tag'].unique()
genome_tags['tag'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                007
# 1       007 (series)
# 2       18th century
# 3              1920s
# 4              1930s
#             ...
# 1123         writing
# 1124           wuxia
# 1125            wwii
# 1126          zombie
# 1127         zombies
# Name: tag, Length: 1128, dtype: object>

# %%
print('\n'.join(map(str, genome_tags['tag'].unique().tolist())))
# Out:
# 007
# 007 (series)
# 18th century
# 1920s
# 1930s
# 1950s
# 1960s
# 1970s
# 1980s
# 19th century
# 3d
# 70mm
# 80s
# 9/11
# aardman
# aardman studios
# abortion
# absurd
# action
# action packed
# adaptation
# adapted from:book
# adapted from:comic
# adapted from:game
# addiction
# adolescence
# adoption
# adultery
# adventure
# affectionate
# afi 100
# afi 100 (laughs)
# afi 100 (movie quotes)
# africa
# afterlife
# aging
# aids
# airplane
# airport
# alaska
# alcatraz
# alcoholism
# alien
# alien invasion
# aliens
# allegory
# almodovar
# alone in the world
# alter ego
# alternate endings
# alternate history
# alternate reality
# alternate universe
# amazing cinematography
# amazing photography
# american civil war
# amnesia
# amy smart
# android(s)/cyborg(s)
# androids
# animal movie
# animals
# animated
# animation
# anime
# antarctica
# anti-hero
# anti-semitism
# anti-war
# apocalypse
# archaeology
# argentina
# arms dealer
# arnold
# art
# art house
# artificial intelligence
# ...

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
unique_tags = tags['tag'].unique()
print('\n'.join(map(str, tags['tag'].unique().tolist())))
# Out:
# Mark Waters
# dark hero
# noir thriller
# bollywood
# screwball comedy
# mars
# neo-noir
# jesus
# dragon
# conspiracy theory
# treasure
# stranded
# Oscar (Best Foreign Language Film)
# New Zealand
# surreal
# unusual
# cute
# emotional
# girls who play boys
# Stephen Chow
# animation
# beautiful
# characters
# Disney
# feminist
# Ice
# music
# musical
# pacing
# royalty
# siblings
# storyline
# themes
# unnecessary villain
# voice acting
# writing
# dark comedy
# drugs
# Nudity (Full Frontal - Notable)
# Nudity (Full Frontal)
# Christopher Guest
# comedy
# music business
# rock and roll
# satire
# witty
# Nudity (Topless - Notable)
# Nudity (Topless)
# sexuality
# teen comedy
# College Humor
# R
# Ryan Reynolds
# Teen movie
# college
# Seann William Scott
# Vince Vaughn
# Will Ferrell
# Funniest Movies
# hilarious
# One of the worst movies of all time
# seen more than once
# Steve Carell
# crude humor
# Seth Rogen
# sex
# sex comedy
# arms dealer
# Nicolas Cage
# Below R
# ...

# %%
ratings.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
#check for null value
print(genome_scores.isnull().sum())
print(genome_tags.isnull().sum())
print(movies.isnull().sum())
print(ratings.isnull().sum())
print(tags.isnull().sum())
# Out:
# movieId      0
# tagId        0
# relevance    0
# dtype: int64
# tagId    0
# tag      0
# dtype: int64
# movieId    0
# title      0
# genres     0
# dtype: int64
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64
# userId        0
# movieId       0
# tag          16
# timestamp     0
# dtype: int64

# %%
missing = tags[tags.isnull().any(axis=1)]
print(missing)
# Out:
#         userId  movieId  tag            timestamp
# 373276  116460      123  NaN  2008-01-04 12:47:47
# 373277  116460      346  NaN  2008-01-04 13:05:46
# 373281  116460     1184  NaN  2008-01-04 13:11:01
# 373288  116460     1785  NaN  2008-01-04 13:06:46
# 373289  116460     2194  NaN  2008-01-04 12:44:37
# 373291  116460     2691  NaN  2008-01-04 12:50:02
# 373299  116460     4103  NaN  2008-01-04 13:05:20
# 373301  116460     4473  NaN  2008-01-04 12:50:40
# 373303  116460     4616  NaN  2008-01-04 13:14:01
# 373319  116460     7624  NaN  2008-01-04 13:11:06
# 373325  116460     8898  NaN  2008-01-04 12:45:57
# 373332  116460    32460  NaN  2008-01-04 12:48:21
# 373334  116460    33826  NaN  2008-01-04 12:45:03
# 373339  116460    36537  NaN  2008-01-04 12:45:36
# 373340  116460    55805  NaN  2008-01-04 12:49:01
# 454615  133634    33826  NaN  2008-09-15 03:55:08

# %%
#Split the genres
genres = movies['genres'].str.get_dummies(sep='|')
movies = pd.concat([movies, genres], axis=1)
movies.drop('genres', axis=1, inplace=True)

# %%
print(len(movies.axes[1]))
# Out:
# 22

# %%
movies.columns
# Out:
# Index(['movieId', 'title', '(no genres listed)', 'Action', 'Adventure',
#        'Animation', 'Children', 'Comedy', 'Crime', 'Documentary', 'Drama',
#        'Fantasy', 'Film-Noir', 'Horror', 'IMAX', 'Musical', 'Mystery',
#        'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western'],
#       dtype='object')
